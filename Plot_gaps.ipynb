# %%
import os
from dateutil.parser import parse as dateutil_parse
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

PATH = 'season_1/'
CLEAN_PATH = PATH+'clean/'

# %matplotlib inline

# %%
train_gap = pd.read_csv(CLEAN_PATH + 'train_gap.csv')

# %%
plt.figure(figsize=(20,10))
train_gap.index.name = 'pieces'

# %%
train_gap = train_gap.drop('pieces', axis = 1)
plt.figure(figsize=(20,10))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-1b0d038c5238> in <module>()
# ----> 1 train_gap = train_gap.drop('pieces', axis = 1)
#       2 plt.figure(figsize=(20,10))
#       3 plt.plot(train_gap)
#
# C:\Users\alienware\Anaconda2\lib\site-packages\pandas\core\generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    1871                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1872             else:
# -> 1873                 new_axis = axis.drop(labels, errors=errors)
#    1874             dropped = self.reindex(**{axis_name: new_axis})
#    1875             try:
#
# C:\Users\alienware\Anaconda2\lib\site-packages\pandas\indexes\base.pyc in drop(self, labels, errors)
#    2964             if errors != 'ignore':
#    2965                 raise ValueError('labels %s not contained in axis' %
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(train_gap)

# %%
plt.plot(train_gap['gap16'])

# %%
train_gap = train_gap.drop('gap1', axis = 1)
plt.plot(train_gap)

# %%
train_gap.plot()

# %%
train_gap.values
# Out:
# array([[  122.,   240.,   359., ...,   161.,   219.,   267.],
#        [  515.,   228.,   425., ...,   197.,   163.,   312.],
#        [ 2273.,   255.,   350., ...,   165.,   140.,   254.],
#        ...,
#        [  185.,   275.,   393., ...,    88.,   147.,   212.],
#        [  298.,   351.,   302., ...,    98.,   146.,   270.],
#        [  275.,   339.,   254., ...,   130.,   198.,   358.]])

# %%
values = np.hstack(train_gap.values)

# %%
len(values)
# Out:
# 3024

# %%
max(values)
# Out:
# 6237.0
